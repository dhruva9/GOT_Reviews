# %%
import pandas as pd
import re
import string
import nltk

# %%
data = pd.read_csv('GOT_Reviews.csv', header=None)
data.columns = ['Comments', 'Ratings']

data.head()
# Out:
#                                                  Comments  Ratings
# 0   Finally, a Show that stays true to it's written roots      9.0
# 1                                   Excellent adaptation.     10.0
# 2            One of the most stunning shows on television     10.0
# 3                        Lord of the Rings - I think not!     10.0
# 4                        Fantasy has never seemed so real     10.0

# %%
data.shape
# Out:
# (1070, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 2 columns):
# Comments    1070 non-null object
# Ratings     1067 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 16.8+ KB

# %% [markdown]
# Data Cleaning
#
# Step 1 - Removing punctuation

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#Remove punctuation in the string

def remove_punct(text):
    text_nonpunct = "".join([char for char in text if char not in string.punctuation])
    
    return text_nonpunct

data['Comments_clean'] = data['Comments'].apply(lambda x: remove_punct(x))

data.head()
# Out:
#                                                  Comments  Ratings  \
# 0   Finally, a Show that stays true to it's written roots      9.0
# 1                                   Excellent adaptation.     10.0
# 2            One of the most stunning shows on television     10.0
# 3                        Lord of the Rings - I think not!     10.0
# 4                        Fantasy has never seemed so real     10.0
#
#                                          Comments_clean  \
# 0   Finally a Show that stays true to its written roots
# 1                                  Excellent adaptation
# 2          One of the most stunning shows on television
# 3                        Lord of the Rings  I think not
# 4                      Fantasy has never seemed so real
#
#                                                    Comments_tokenized  \
# 0  [, finally, a, show, that, stays, true, to, it, s, written, roots]
# 1                                         [, excellent, adaptation, ]
# 2             [, one, of, the, most, stunning, shows, on, television]
# 3                           [, lord, of, the, rings, i, think, not, ]
# 4                           [, fantasy, has, never, seemed, so, real]
#
#                                  Comments_nonstop
# 0  [, finally, show, stays, true, written, roots]
# 1                     [, excellent, adaptation, ]
# 2            [, one, stunning, shows, television]
# 3                        [, lord, rings, think, ]
# 4                [, fantasy, never, seemed, real]

# %%
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

data['Comments_tokenized'] = data['Comments'].apply(lambda x: tokenize(x.lower()))

data.head()
# Out:
#                                                  Comments  Ratings  \
# 0   Finally, a Show that stays true to it's written roots      9.0
# 1                                   Excellent adaptation.     10.0
# 2            One of the most stunning shows on television     10.0
# 3                        Lord of the Rings - I think not!     10.0
# 4                        Fantasy has never seemed so real     10.0
#
#                                          Comments_clean  \
# 0   Finally a Show that stays true to its written roots
# 1                                  Excellent adaptation
# 2          One of the most stunning shows on television
# 3                        Lord of the Rings  I think not
# 4                      Fantasy has never seemed so real
#
#                                                    Comments_tokenized  \
# 0  [, finally, a, show, that, stays, true, to, it, s, written, roots]
# 1                                         [, excellent, adaptation, ]
# 2             [, one, of, the, most, stunning, shows, on, television]
# 3                           [, lord, of, the, rings, i, think, not, ]
# 4                           [, fantasy, has, never, seemed, so, real]
#
#                                  Comments_nonstop
# 0  [, finally, show, stays, true, written, roots]
# 1                     [, excellent, adaptation, ]
# 2            [, one, stunning, shows, television]
# 3                        [, lord, rings, think, ]
# 4                [, fantasy, never, seemed, real]

# %%
#Remove stopwords
stopword = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text

data['Comments_nonstop'] = data['Comments_tokenized'].apply(lambda x: remove_stopwords(x))

data.head()
# Out:
#                                                  Comments  Ratings  \
# 0   Finally, a Show that stays true to it's written roots      9.0
# 1                                   Excellent adaptation.     10.0
# 2            One of the most stunning shows on television     10.0
# 3                        Lord of the Rings - I think not!     10.0
# 4                        Fantasy has never seemed so real     10.0
#
#                                          Comments_clean  \
# 0   Finally a Show that stays true to its written roots
# 1                                  Excellent adaptation
# 2          One of the most stunning shows on television
# 3                        Lord of the Rings  I think not
# 4                      Fantasy has never seemed so real
#
#                                                    Comments_tokenized  \
# 0  [, finally, a, show, that, stays, true, to, it, s, written, roots]
# 1                                         [, excellent, adaptation, ]
# 2             [, one, of, the, most, stunning, shows, on, television]
# 3                           [, lord, of, the, rings, i, think, not, ]
# 4                           [, fantasy, has, never, seemed, so, real]
#
#                                  Comments_nonstop
# 0  [, finally, show, stays, true, written, roots]
# 1                     [, excellent, adaptation, ]
# 2            [, one, stunning, shows, television]
# 3                        [, lord, rings, think, ]
# 4                [, fantasy, never, seemed, real]

# %% [markdown]
# Lemmatization

# %%
wn = nltk.WordNetLemmatizer()

# %%
def lemmatizing(tokenized_text):
    text = [wn.lemmatize(word) for word in tokenized_text]
    return text

data['Comments_lemmatized'] = data['Comments_nonstop'].apply(lambda x: lemmatizing(x))

data.head(10)
# Out:
#                                                               Comments  \
# 0                Finally, a Show that stays true to it's written roots
# 1                                                Excellent adaptation.
# 2                         One of the most stunning shows on television
# 3                                     Lord of the Rings - I think not!
# 4                                     Fantasy has never seemed so real
# 5                              Excellent, Raw, Brutal and to the point
# 6                                       This TV series is magnificent!
# 7   Fantastic! The scale was amazing and it stayed loyal to the books!
# 8                                                   Fresh and Exciting
# 9                                         This one will blow you away!
#
#    Ratings                                                     Comments_clean  \
# 0      9.0                Finally a Show that stays true to its written roots
# 1     10.0                                               Excellent adaptation
# 2     10.0                       One of the most stunning shows on television
# 3     10.0                                     Lord of the Rings  I think not
# 4     10.0                                   Fantasy has never seemed so real
# 5     10.0                              Excellent Raw Brutal and to the point
# 6     10.0                                      This TV series is magnificent
# 7     10.0   Fantastic The scale was amazing and it stayed loyal to the books
# 8     10.0                                                 Fresh and Exciting
# 9     10.0                                        This one will blow you away
#
#                                                                   Comments_tokenized  \
# 0                 [, finally, a, show, that, stays, true, to, it, s, written, roots]
# 1                                                        [, excellent, adaptation, ]
# 2                            [, one, of, the, most, stunning, shows, on, television]
# 3                                          [, lord, of, the, rings, i, think, not, ]
# 4                                          [, fantasy, has, never, seemed, so, real]
# 5                                    [, excellent, raw, brutal, and, to, the, point]
# 6                                            [, this, tv, series, is, magnificent, ]
# 7  [, fantastic, the, scale, was, amazing, and, it, stayed, loyal, to, the, books, ]
# 8                                                           [, fresh, and, exciting]
# 9                                             [, this, one, will, blow, you, away, ]
#
#                                         Comments_nonstop  \
# 0         [, finally, show, stays, true, written, roots]
# 1                            [, excellent, adaptation, ]
# 2                   [, one, stunning, shows, television]
# 3                               [, lord, rings, think, ]
# 4                       [, fantasy, never, seemed, real]
# 5                      [, excellent, raw, brutal, point]
# 6                          [, tv, series, magnificent, ]
# 7  [, fantastic, scale, amazing, stayed, loyal, books, ]
# 8                                    [, fresh, exciting]
# 9                                  [, one, blow, away, ]
#
#                                     Comments_lemmatized
# 0          [, finally, show, stay, true, written, root]
# 1                           [, excellent, adaptation, ]
# 2                   [, one, stunning, show, television]
# 3                               [, lord, ring, think, ]
# 4                      [, fantasy, never, seemed, real]
# 5                     [, excellent, raw, brutal, point]
# 6                         [, tv, series, magnificent, ]
# 7  [, fantastic, scale, amazing, stayed, loyal, book, ]
# 8                                   [, fresh, exciting]
# 9                                 [, one, blow, away, ]
